# %% [markdown]
# <a href="https://colab.research.google.com/github/Swetha261106/MLP-/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
colors=[ "Red", "blue", "pink", "yellow", "black"]
combined_list = [109, 80.9, "Ashifa", True]
a=[5, 34, 98, 20, 25]
colors.append("white")
colors.insert(1,"Orange")
print(colors)
colors.pop()
print(colors)
print(len(colors))
print(len(combined_list))
print(min(a))
print(max(a))
a.sort()
print(a)
a.reverse()
print(a)
# Out:
# ['Red', 'Orange', 'blue', 'pink', 'yellow', 'black', 'white']
# ['Red', 'Orange', 'blue', 'pink', 'yellow', 'black']
# 6
# 4
# 5
# 98
# [5, 20, 25, 34, 98]
# [98, 34, 25, 20, 5]

# %%
colors=["Red", "blue", "pink", "yellow", "black"]
print(colors[0])
print(colors[-5])
print(colors[4])
print(colors[-1])
# Out:
# Red
# Red
# black
# black

# %%
numbers = [2, 4, 6, 8, 10]
colors = ["Red", "blue", "pink", "yellow", "Black"]
combined_list = [109,80.9," Ashifa", True]
emptylist = []
print(numbers, colors, combined_list, emptylist)
# Out:
# [2, 4, 6, 8, 10] ['Red', 'blue', 'pink', 'yellow', 'Black'] [109, 80.9, ' Ashifa', True] []

# %%
student=[]
student.append ("Swetha")
student.append("Ilas")
student.append("Niha")
student.append ("Yash")
for i in student:
	print(i)
student.insert(1,"Mathu")
print(student)
student.remove("Yash")
print(student)
student.sort()
print (student)
for i in student:
	print(i)
a=input("Enter the name: ")
for i in student:
	if i==a:
		print("The name is present in the list")
	else:
		print("The name is not peresent in the list")
	break
# Out:
# Swetha
# Ilas
# Niha
# Yash
# ['Swetha', 'Mathu', 'Ilas', 'Niha', 'Yash']
# ['Swetha', 'Mathu', 'Ilas', 'Niha']
# ['Ilas', 'Mathu', 'Niha', 'Swetha']
# Ilas
# Mathu
# Niha
# Swetha

# %%
s=[3,8,9,10, 45, 22]
w=0
for n in s:
	if n%2==0:
		w+=1
		print(w)
