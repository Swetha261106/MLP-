# %% [markdown]
# <a href="https://colab.research.google.com/github/Swetha261106/MLP-/blob/main/Aug14task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.DataFrame({"Gender":["male","female","male","female"]})
print(df)
print(pd.get_dummies(df))
# Out:
#    Gender
# 0    male
# 1  female
# 2    male
# 3  female
#    Gender_female  Gender_male
# 0          False         True
# 1           True        False
# 2          False         True
# 3           True        False
